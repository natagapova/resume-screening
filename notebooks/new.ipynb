# %%
import pandas as pd
df = pd.read_csv("../data/processed/test.csv")
print(df.columns.tolist())
print(df.head(2))
# Out:
# ['resume_text', 'label', 'city_group', 'gender', 'age_group']
#                                          resume_text            label  \
# 0  Опыт работы 7 лет 8 месяцев IT специалист, сис...    it специалист
# 1  Опыт работы 12 лет 5 месяцев Июль 2018 — по на...  менеджер проект
#
#   city_group gender age_group
# 0      Other   Male   Unknown
# 1     Москва   Male   Unknown

# %%
print(df['gender'].unique())
print(df['age_group'].unique())
print(df['city_group'].unique())
# Out:
# <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# <ArrowStringArray>
# ['Unknown', '26–35', '22–25', '36–50', '50+', '18–21', '<18']
# Length: 7, dtype: str
# <ArrowStringArray>
# [           'Other',           'Москва',  'Санкт-Петербург',
#       'Новосибирск',           'Липецк',         'Кемерово',
#               'Уфа',           'Тюмень',        'Краснодар',
#      'Екатеринбург',   'Ростов-на-Дону',       'Ставрополь',
#         'Ярославль',            'Минск',           'Самара',
#           'Саратов',           'Ижевск',         'Тольятти',
#           'Иркутск',            'Томск',      'Калининград',
#            'Алматы',      'Симферополь',             'Омск',
#        'Красноярск',           'Казань', 'Набережные Челны',
#         'Хабаровск',            'Пенза',          'Воронеж',
#   'Нижний Новгород',            'Тверь',        'Ульяновск',
#             'Пермь',        'Волгоград',             'Сочи',
# ...
